# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import cv2
import sys
sys.path.append('/home/g007markphillip/model_artifacts2/')
from src.data.dataset import TrainGenerator,ValGenerator

# %%
train_dataset = TrainGenerator(2).batch(32)

# %%
images = list(train_dataset.take(1))[0][0].numpy()
labels  = list(train_dataset.take(1))[0][1].numpy()
# Out:
# Exception ignored in: <generator object TrainGenerator.generator at 0x7fc3017f2f90>
# Traceback (most recent call last):
#   File "/home/g007markphillip/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 727, in iterator_completed
#     del self._iterators[iterator_id]
# RuntimeError: generator ignored GeneratorExit
# Exception ignored in: <generator object TrainGenerator.generator at 0x7fc3017f2120>
# Traceback (most recent call last):
#   File "/home/g007markphillip/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 727, in iterator_completed
#     del self._iterators[iterator_id]
# RuntimeError: generator ignored GeneratorExit

# %%
fig,axes = plt.subplots(8,4,figsize=(10,25))
a=0
for i in range(8):
    for j in range(4):
        axes[i,j].imshow(images[a]/255)
        axes[i,j].set_title(labels[a])
        a+=1
        
plt.show()
# Out:
# /home/g007markphillip/anaconda3/envs/tf/lib/python3.9/site-packages/matplotlib/text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
